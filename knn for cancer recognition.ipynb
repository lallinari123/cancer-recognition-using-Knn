# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import  seaborn as sns
from scipy.stats import zscore

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
NNH=KNeighborsClassifier(n_neighbors=5,weights='distance')

# %%
bc_df=pd.read_csv("C:/Users/Narasimha Rao/OneDrive/Desktop/wisc.csv")

# %%
bc_df.shape
# Out:
# (569, 32)

# %%
bc_df.dtypes
# Out:
# id                     int64
# diagnosis             object
# radius_mean          float64
# texture_mean         float64
# perimeter_mean       float64
# area_mean            float64
# smoothness_mean      float64
# compactness_mean     float64
# concavity_mean       float64
# points_mean          float64
# symmetry_mean        float64
# dimension_mean       float64
# radius_se            float64
# texture_se           float64
# perimeter_se         float64
# area_se              float64
# smoothness_se        float64
# compactness_se       float64
# concavity_se         float64
# points_se            float64
# symmetry_se          float64
# dimension_se         float64
# radius_worst         float64
# texture_worst        float64
# perimeter_worst      float64
# area_worst           float64
# smoothness_worst     float64
# compactness_worst    float64
# concavity_worst      float64
# points_worst         float64
# symmetry_worst       float64
# dimension_worst      float64
# ...

# %% [markdown]
# object type is string type..as none of the algorithm works on a strings..so we have to chang type of dignosis column

# %%
bc_df["diagnosis"]=bc_df.diagnosis.astype("category")

# %%
bc_df.dtypes
# Out:
# id                      int64
# diagnosis            category
# radius_mean           float64
# texture_mean          float64
# perimeter_mean        float64
# area_mean             float64
# smoothness_mean       float64
# compactness_mean      float64
# concavity_mean        float64
# points_mean           float64
# symmetry_mean         float64
# dimension_mean        float64
# radius_se             float64
# texture_se            float64
# perimeter_se          float64
# area_se               float64
# smoothness_se         float64
# compactness_se        float64
# concavity_se          float64
# points_se             float64
# symmetry_se           float64
# dimension_se          float64
# radius_worst          float64
# texture_worst         float64
# perimeter_worst       float64
# area_worst            float64
# smoothness_worst      float64
# compactness_worst     float64
# concavity_worst       float64
# points_worst          float64
# symmetry_worst        float64
# ...

# %% [markdown]
# category is stored as numbers internally

# %% [markdown]
# for xample employee id..we can not use empid in any mathematical calculations..they are only nemerical values

# %%
bc_df.describe().transpose()
# Out:
#                    count          mean           std          min  \
# id                 569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean        569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean       569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean     569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean          569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean    569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean   569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean     569.0  8.879932e-02  7.971981e-02     0.000000
# points_mean        569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean      569.0  1.811619e-01  2.741428e-02     0.106000
# dimension_mean     569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se          569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se         569.0  1.216853e+00  5.516484e-01     0.360200
# ...

# %% [markdown]
# look at in to the data before model building..
# is  there any relationship between dignosis and other features..
# in knn we dont have any model..
# in dignosis after putting the filter we have B and M..WHAT are the short forms meaning
# in some features we have 0..is it missing at random or it is a value

# %% [markdown]
# after sorting id of patients we observr some jumps ..where is the remaining data..
# we have to ask about data..if there is a valid reason we move on
#
#
# in radius_mean...if we draw a grapg for distibution..we have min max..mean,,q1,q2,q3
# the tails are distance between q1 and min and max and q3
#
# there are outliers because of these tails are there

# %%
bc_df.groupby(["diagnosis"]).count()
# Out:
#             id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# diagnosis
# B          357          357           357             357        357
# M          212          212           212             212        212
#
#            smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# diagnosis
# B                      357               357             357          357
# M                      212               212             212          212
#
#            symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# diagnosis                 ...
# B                    357  ...           357            357              357
# M                    212  ...           212            212              212
#
#            area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# diagnosis
# B                 357               357                357              357
# M                 212               212                212              212
#
# ...

# %% [markdown]
# drop thr first column we are not using this in modeling

# %%
bc_feature_df=bc_df.drop(labels="id",axis=1)

# %% [markdown]
# we use group by for diagnosis...it separates the data based on the category..
# in our dataset..we have B=357 and M=212
#
# our model best identifies B cases than M cases...
# is our model can identify all the cases using 357 benain  data points
# and 212 cases by using 212 malignant case
#
# our models can get malignant as malignant
# aditional sampling or reduce the benain
# we didnt reduce the we have add the data
#
#
# the model that we crete model on large data it is better modl

# %%
bc_feature_df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           B        12.32         12.39           78.85      464.1
# 1           B        10.60         18.95           69.28      346.4
# 2           B        11.04         16.83           70.92      373.2
# 3           B        11.28         13.39           73.00      384.8
# 4           B        15.19         13.21           97.65      711.8
# ..        ...          ...           ...             ...        ...
# 564         B        13.17         18.22           84.28      537.3
# 565         B        10.26         14.71           66.20      321.6
# 566         M        15.28         22.41           98.92      710.6
# 567         B        14.53         13.98           93.86      644.2
# 568         M        21.37         15.10          141.30     1386.0
#
#      smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0            0.10280           0.06981         0.03987      0.03700
# ...

# %%
bc_feature_df1=bc_feature_df.drop(labels="diagnosis",axis=1)

# %%
bc_feature_df1
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          12.32         12.39           78.85      464.1          0.10280
# 1          10.60         18.95           69.28      346.4          0.09688
# 2          11.04         16.83           70.92      373.2          0.10770
# 3          11.28         13.39           73.00      384.8          0.11640
# 4          15.19         13.21           97.65      711.8          0.07963
# ..           ...           ...             ...        ...              ...
# 564        13.17         18.22           84.28      537.3          0.07466
# 565        10.26         14.71           66.20      321.6          0.09882
# 566        15.28         22.41           98.92      710.6          0.09057
# 567        14.53         13.98           93.86      644.2          0.10990
# 568        21.37         15.10          141.30     1386.0          0.10010
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
bc_feature_df1_z=bc_feature_df1.apply(zscore)

# %%
bc_feature_df1_z.describe()
# Out:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.287781e-16 -7.373520e-16   -1.303390e-16 -2.239958e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean   points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02  5.690000e+02
# mean      1.660457e-16      1.882891e-16    5.112099e-17 -4.760886e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00  1.000880e+00
# min      -3.112085e+00     -1.610136e+00   -1.114873e+00 -1.261820e+00
# ...

# %% [markdown]
# z score is equl to =x-mean/standard deviation....

# %% [markdown]
# knn is used for distance calculations..so all are in same scale thats why we used scaling

# %%
bc_labels=bc_df["diagnosis"]

# %%
x=np.array(bc_feature_df1_z)

# %%
x.shape
# Out:
# (569, 30)

# %%
y=np.array(bc_labels)

# %%
y.shape
# Out:
# (569,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)pre

# %%
NNH.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
predicted_labels=NNH.predict(x_test)

# %%
NNH.score(x_test,y_test)
# Out:
# 0.9649122807017544

# %%
from  sklearn import metrics
print(metrics.confusion_matrix(y_test,predicted_labels))
# Out:
# [[112   2]
#  [  4  53]]
